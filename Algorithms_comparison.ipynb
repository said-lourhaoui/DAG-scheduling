# %% [markdown]
# # Comparison between the two algorithms for differnet DAG parameters

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
results_all= pd.read_csv("results_all.csv")

# %%
results_all.head(400)
# Out:
#      Unnamed: 0  n_nodes  n_processors  width  density  regular  jump  \
# 0             0       10             2    0.5      0.1      0.1     2
# 1             1       10             2    0.5      0.1      0.5     2
# 2             2       10             2    0.5      0.1      1.0     2
# 3             3       10             2    0.5      0.5      0.1     2
# 4             4       10             2    0.5      0.5      0.5     2
# ..          ...      ...           ...    ...      ...      ...   ...
# 395         395       60             6    1.0      1.0      1.0     2
# 396         396       60             6   10.0      0.1      0.1     2
# 397         397       60             6   10.0      0.1      0.5     2
# 398         398       60             6   10.0      0.1      1.0     2
# 399         399       60             6   10.0      0.5      0.1     2
#
#      GA_makespan  proposedAlgo
# 0          132.0         114.0
# 1          150.0         126.0
# ...

# %% [markdown]
# # No of nodes influence

# %%
nodes_mean = results_all.groupby(["n_nodes"]).mean().reset_index()

plt.plot(nodes_mean["n_nodes"], nodes_mean["GA_makespan"] , label= 'GA' )
plt.plot(nodes_mean["n_nodes"], nodes_mean["proposedAlgo"] , label= 'proposed algo' )
plt.xlabel("No of nodes")
plt.ylabel("Makespan")
plt.title("Makespan vs No of nodes for both algorithms")
plt.legend()
plt.show()
#nodes_mean.head()

# %%
nodes_mean.plot(x="n_nodes", y = ["GA_makespan", "proposedAlgo"], kind='bar', label = ["GA", 'proposedAlgo'] )
plt.xlabel("No of nodes")
plt.ylabel("Makespan")
plt.title("Makespan vs No of nodes for both algorithms")
plt.show()

# %% [markdown]
# # No of processors influence

# %%
processors_mean = results_all.groupby(["n_processors"]).mean().reset_index()

plt.plot(processors_mean["n_processors"], processors_mean["GA_makespan"] , label= 'GA' )
plt.plot(processors_mean["n_processors"], processors_mean["proposedAlgo"] , label= 'proposed algo' )
plt.xlabel("No of processors")
plt.ylabel("Makespan")
plt.title("Makespan vs No of processors for both algorithms")
plt.legend()
plt.show()
#processors_mean.head()

# %%
processors_mean.plot(x="n_processors", y = ["GA_makespan", "proposedAlgo"], kind='bar', label = ["GA", 'proposedAlgo'] )
plt.xlabel("No of processors")
plt.ylabel("Makespan")
plt.title("Makespan vs No of processors for both algorithms")
plt.show()

# %% [markdown]
# # Width of the graph influence

# %%
fat_mean = results_all.groupby(["width"]).mean().reset_index()

plt.plot(fat_mean["width"], fat_mean["GA_makespan"] , label= 'GA' )
plt.plot(fat_mean["width"], fat_mean["proposedAlgo"] , label= 'proposed algo' )
plt.xlabel("Width")
plt.ylabel("Makespan")
plt.title("Makespan vs width of the DAG for both algorithms")
plt.legend()
plt.show()
#fat_mean.head()

# %%
fat_mean.plot(x="width", y = ["GA_makespan", "proposedAlgo"], kind='bar', label = ["GA", 'proposedAlgo'] )
plt.xlabel("Width")
plt.ylabel("Makespan")
plt.title("Makespan vs width of the DAG for both algorithms")
plt.legend()
plt.show()

# %% [markdown]
# # Density of the graph influence

# %%
density_mean = results_all.groupby(["density"]).mean().reset_index()

plt.plot(density_mean["density"], density_mean["GA_makespan"] , label= 'GA' )
plt.plot(density_mean["density"], density_mean["proposedAlgo"] , label= 'proposed algo' )
plt.xlabel("Density")
plt.ylabel("Makespan")
plt.title("Makespan vs density of the DAG for both algorithms")
plt.legend()
plt.show()
#density_mean.head()

# %%
density_mean.plot(x="density", y = ["GA_makespan", "proposedAlgo"], kind='bar', label = ["GA", 'proposedAlgo'] )
plt.xlabel("Density")
plt.ylabel("Makespan")
plt.title("Makespan vs density of the DAG for both algorithms")
plt.legend()
plt.show()

# %% [markdown]
# # Regularity of the graph influence

# %%
regularity_mean = results_all.groupby(["regular"]).mean().reset_index()

plt.plot(regularity_mean["regular"], regularity_mean["GA_makespan"] , label= 'GA' )
plt.plot(regularity_mean["regular"], regularity_mean["proposedAlgo"] , label= 'proposed algo' )
plt.xlabel("Regularity")
plt.ylabel("Makespan")
plt.title("Makespan vs regularity of the DAG for both algorithms")
plt.legend()
plt.show()
#regularity_mean.head()

# %%
regularity_mean.plot(x="regular", y = ["GA_makespan", "proposedAlgo"], kind='bar', label = ["GA", 'proposedAlgo'] )
plt.xlabel("Regularity")
plt.ylabel("Makespan")
plt.title("Makespan vs regularity of the DAG for both algorithms")
plt.legend()
plt.show()
